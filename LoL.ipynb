# %% [markdown]
# # HomePage

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://www.leagueoflegends.com/fr-fr/champions/")

soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html data-riot-locale="fr-fr" data-riot-region="euw" lang="fr-fr"><head><meta charset="utf-8"/><meta content="ie=edge" http-equiv="x-ua-compatible"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><script>try {
#               document.documentElement.classList.add('js');
#
#               var safari = /^((?!chrome|android).)*safari/i.test(window.navigator.userAgent);
#               var ie11 = !!window.navigator.userAgent.match(/Trident.*rv:11./);
#               var ie10 = !ie11 && (window.navigator.userAgent.indexOf('MSIE ') > -1);
#               var edge = (window.navigator.userAgent.indexOf('Edge/') > -1);
#
#               if (ie10 || ie11 || edge) document.documentElement.classList.add('is-ms');
#               if (ie10 || ie11) document.documentElement.classList.add('is-ms-ie');
#               if (ie10) document.documentElement.classList.add('is-ms-10');
# ...

# %%
champions = soup.find('div', class_='style__List-sc-13btjky-2').find_all('a')

# %%
# Images
champions[0].find('img').get('src')

# Names
champions[0].find('span', 'style__Name-sc-n3ovyt-2').text
# Out:
# 'Aatrox'

# %%
# Images
champions[0].find('img').get('src')
# Out:
# 'https://images.contentstack.io/v3/assets/blt731acb42bb3d1659/blt570145160dd39dca/5db05fa8347d1c6baa57be25/RiotX_ChampionList_aatrox.jpg?quality=90&width=250'

# %%
champions[0].get('href').split('/')[-2]
# Out:
# 'aatrox'

# %%
url = 'https://www.leagueoflegends.com/fr-fr/champions/'

# %%
champions[0].get('href').split('/')[-2]

# %%
champions[0].get('href').split('/')[-2]
# Out:
# 'aatrox'

# %%
champions[0].get('href').split('/')[-2]
# Out:
# 'aatrox'

# %%
url + champions[0].get('href').split('/')[-2]
# Out:
# 'https://www.leagueoflegends.com/fr-fr/champions/aatrox'

# %% [markdown]
# # Champions

# %%
champion_link = url + champions[0].get('href').split('/')[-2]
response_champion = requests.get(champion_link)
soup_champion = BeautifulSoup(response_champion.text, "html.parser")

# %%
champion_link
# Out:
# 'https://www.leagueoflegends.com/fr-fr/champions//fr-fr/champions/aatrox/aatrox'

# %%
soup_champion
# Out:
# <!DOCTYPE html>
# <html data-riot-locale="fr-fr" lang="fr-fr"><head><meta charset="utf-8"/><meta content="ie=edge" http-equiv="x-ua-compatible"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><script>try {
#               document.documentElement.classList.add('js');
#
#               var safari = /^((?!chrome|android).)*safari/i.test(window.navigator.userAgent);
#               var ie11 = !!window.navigator.userAgent.match(/Trident.*rv:11./);
#               var ie10 = !ie11 && (window.navigator.userAgent.indexOf('MSIE ') > -1);
#               var edge = (window.navigator.userAgent.indexOf('Edge/') > -1);
#
#               if (ie10 || ie11 || edge) document.documentElement.classList.add('is-ms');
#               if (ie10 || ie11) document.documentElement.classList.add('is-ms-ie');
#               if (ie10) document.documentElement.classList.add('is-ms-10');
#               if (ie11) document.documentElement.classList.add('is-ms-11');
# ...

# %%
soup_champion.find('div', 'style__Desc-sc-8gkpub-9 jheTpK').text
# Out:
# 'Autrefois, Aatrox et ses frères étaient honorés pour avoir défendu Shurima contre le Néant. Mais ils finirent par devenir une menace plus grande encore pour Runeterra\xa0: la ruse et la sorcellerie furent employées pour les battre. Cependant, après des... Voir plus'

# %%
soup_champion.find('div', 'style__SpecsItemValue-sc-8gkpub-15 fTPDyp').text
# Out:
# 'Combattant'

# %% [markdown]
# # Classement des joueurs

# %%
import requests
from bs4 import BeautifulSoup

response_joueurs = requests.get("https://www.leagueofgraphs.com/fr/rankings/summoners/euw")

soup_joueurs = BeautifulSoup(response_joueurs.text, "html.parser")
soup_joueurs
# Out:
# <!DOCTYPE html>
#
# <html lang="fr" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,500,700" media="none" onload="this.media='all'" rel="stylesheet" type="text/css"/> <link href="//lolg-cdn.porofessor.gg/style.css?v=1702484714" rel="stylesheet" type="text/css">
# <link href="//lolg-cdn.porofessor.gg/style.sprite.css?v=bb8d765f53a1085cd96eeb8c2325efdc" rel="stylesheet" type="text/css"/>
# <script src="//lolg-cdn.porofessor.gg/jquery.js?v=3"></script>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="fr" http-equiv="content-language"/>
# <meta content="League of Legends - Classement des invocateurs, sorts, champions. Popularité des champions, taux de victoire, meilleurs items, et meilleurs sorts d'invocateurs" name="description"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
soup_joueurs.find('tr')

# %%
soup_joueurs.text
# Out:
# "\n\n\n\n \n\n\n\n\n\n\n\n\n\nErreur\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                Accueil                            \n\n\nChampions\n\n\n\n                                               Vue d'ensemble                                        \n\n\n\n                                               Champions stats                                        \n\n\n\n                                               ProBuilds                                        \n\n\n\n                                               Compos / Counters                                        \n\n\n\n                                               Runes                                        \n\n\n\n                                               Ordre des skills                                        \n\n\n\n                                               Objets          
# ...
